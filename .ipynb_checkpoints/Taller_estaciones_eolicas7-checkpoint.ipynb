# %% [markdown]
# APRENDIZ: Veronica Perez Zea
#
# FICHA: 1751400
#
# FECHA DE INICIO: 06/12/2019
#
# TALLER ESTACIONES EOLICAS

# %% [markdown]
# REQUERIMIENTO Nº7
#
# Generar una tabla que contenga las siguientes columnas:
#
# -Estación.
#
# -Mes (MM).
#
# -Hora (HH).
#
# -Velocidad media para ese mes y esa hora calculada sobre todos los datos.

# %%
import time,datetime
import pandas
def archivo (file):
    estacion7 = open('C:/Users/VERONICA/Desktop/SENA/5t/PYTHON/files/06/Estacion3.csv', 'r').readlines()
    estacion7 = estacion7[1:]
    estacion7 = [row[0:-1] for row in estacion7]
    estacion7 = [row.split(';') for row in estacion7]
    return estacion7

# %%
tabla7= archivo('C:/Users/VERONICA/Desktop/SENA/5t/PYTHON/files/06/Estacion3.csv')

# %%
[[row[0].lower()]for row in tabla7]
tabla7=[[str('Estacion3')]+ row for row in tabla7]

# %%
def cambio(s):
    return datetime.datetime.strptime(s,'%d/%m/%y').strftime('%Y/%m/%d')

# %%
tabla7= [[row[0],cambio(row[1]),row[2],row[3],row[4]] for row in tabla7]

# %%
def MONTH(s):
    return datetime.datetime.strptime(s,'%Y/%m/%d').month

# %%
tabla7=[[MONTH(row[1])]+ row for row in tabla7]

# %%
tabla7=[[row[1],row[2],row[3],row[0]]for row in tabla7]

# %%
def HORA(s):
    return datetime.datetime.strptime(s,'%H:%M:%S').strftime('%H')

# %%
tabla7=[[HORA(row[2])]+ row for row in tabla7]

# %%
tabla7=[[row[1],row[3],row[0],row[2],row[4]]for row in tabla7]

# %%
tabla7
# Out:
# [['Estacion3', '13:20:00', '13', '2005/03/06', 3],
#  ['Estacion3', '13:30:00', '13', '2005/03/06', 3],
#  ['Estacion3', '13:40:00', '13', '2005/03/06', 3],
#  ['Estacion3', '13:50:00', '13', '2005/03/06', 3],
#  ['Estacion3', '14:00:00', '14', '2005/03/06', 3],
#  ['Estacion3', '14:10:00', '14', '2005/03/06', 3],
#  ['Estacion3', '14:30:00', '14', '2005/03/06', 3],
#  ['Estacion3', '14:40:00', '14', '2005/03/06', 3],
#  ['Estacion3', '14:50:00', '14', '2005/03/06', 3],
#  ['Estacion3', '15:00:00', '15', '2005/03/06', 3],
#  ['Estacion3', '15:10:00', '15', '2005/03/06', 3],
#  ['Estacion3', '15:20:00', '15', '2005/03/06', 3],
#  ['Estacion3', '15:30:00', '15', '2005/03/06', 3],
#  ['Estacion3', '15:40:00', '15', '2005/03/06', 3],
#  ['Estacion3', '15:50:00', '15', '2005/03/06', 3],
#  ['Estacion3', '16:00:00', '16', '2005/03/06', 3],
#  ['Estacion3', '16:10:00', '16', '2005/03/06', 3],
#  ['Estacion3', '16:20:00', '16', '2005/03/06', 3],
#  ['Estacion3', '16:30:00', '16', '2005/03/06', 3],
#  ['Estacion3', '16:40:00', '16', '2005/03/06', 3],
#  ['Estacion3', '16:50:00', '16', '2005/03/06', 3],
#  ['Estacion3', '17:00:00', '17', '2005/03/06', 3],
#  ['Estacion3', '17:10:00', '17', '2005/03/06', 3],
#  ['Estacion3', '17:20:00', '17', '2005/03/06', 3],
#  ['Estacion3', '17:30:00', '17', '2005/03/06', 3],
#  ['Estacion3', '17:40:00', '17', '2005/03/06', 3],
#  ['Estacion3', '17:50:00', '17', '2005/03/06', 3],
#  ['Estacion3', '18:00:00', '18', '2005/03/06', 3],
#  ['Estacion3', '18:10:00', '18', '2005/03/06', 3],
#  ['Estacion3', '18:20:00', '18', '2005/03/06', 3],
#  ['Estacion3', '18:30:00', '18', '2005/03/06', 3],
#  ['Estacion3', '18:40:00', '18', '2005/03/06', 3],
#  ['Estacion3', '18:50:00', '18', '2005/03/06', 3],
#  ['Estacion3', '19:00:00', '19', '2005/03/06', 3],
#  ['Estacion3', '19:10:00', '19', '2005/03/06', 3],
#  ['Estacion3', '19:20:00', '19', '2005/03/06', 3],
#  ['Estacion3', '19:30:00', '19', '2005/03/06', 3],
#  ['Estacion3', '19:40:00', '19', '2005/03/06', 3],
#  ['Estacion3', '19:50:00', '19', '2005/03/06', 3],
#  ['Estacion3', '20:00:00', '20', '2005/03/06', 3],
#  ['Estacion3', '20:10:00', '20', '2005/03/06', 3],
#  ['Estacion3', '20:20:00', '20', '2005/03/06', 3],
#  ['Estacion3', '20:30:00', '20', '2005/03/06', 3],
#  ['Estacion3', '20:40:00', '20', '2005/03/06', 3],
#  ['Estacion3', '20:50:00', '20', '2005/03/06', 3],
#  ['Estacion3', '21:00:00', '21', '2005/03/06', 3],
#  ['Estacion3', '21:10:00', '21', '2005/03/06', 3],
#  ['Estacion3', '21:20:00', '21', '2005/03/06', 3],
#  ['Estacion3', '21:30:00', '21', '2005/03/06', 3],
#  ['Estacion3', '21:40:00', '21', '2005/03/06', 3],
#  ['Estacion3', '21:50:00', '21', '2005/03/06', 3],
#  ['Estacion3', '22:00:00', '22', '2005/03/06', 3],
#  ['Estacion3', '22:10:00', '22', '2005/03/06', 3],
#  ['Estacion3', '22:20:00', '22', '2005/03/06', 3],
#  ['Estacion3', '22:30:00', '22', '2005/03/06', 3],
#  ['Estacion3', '22:40:00', '22', '2005/03/06', 3],
#  ['Estacion3', '22:50:00', '22', '2005/03/06', 3],
#  ['Estacion3', '0:00:00', '00', '2005/03/07', 3],
#  ['Estacion3', '0:10:00', '00', '2005/03/07', 3],
#  ['Estacion3', '0:20:00', '00', '2005/03/07', 3],
#  ['Estacion3', '0:30:00', '00', '2005/03/07', 3],
#  ['Estacion3', '0:40:00', '00', '2005/03/07', 3],
#  ['Estacion3', '0:50:00', '00', '2005/03/07', 3],
#  ['Estacion3', '1:00:00', '01', '2005/03/07', 3],
#  ['Estacion3', '1:10:00', '01', '2005/03/07', 3],
#  ['Estacion3', '1:20:00', '01', '2005/03/07', 3],
#  ['Estacion3', '1:30:00', '01', '2005/03/07', 3],
#  ['Estacion3', '1:40:00', '01', '2005/03/07', 3],
#  ['Estacion3', '1:50:00', '01', '2005/03/07', 3],
#  ['Estacion3', '2:00:00', '02', '2005/03/07', 3],
#  ['Estacion3', '2:10:00', '02', '2005/03/07', 3],
#  ['Estacion3', '2:20:00', '02', '2005/03/07', 3],
#  ['Estacion3', '2:30:00', '02', '2005/03/07', 3],
#  ['Estacion3', '2:40:00', '02', '2005/03/07', 3],
#  ['Estacion3', '2:50:00', '02', '2005/03/07', 3],
#  ['Estacion3', '3:00:00', '03', '2005/03/07', 3],
#  ['Estacion3', '3:10:00', '03', '2005/03/07', 3],
#  ['Estacion3', '3:20:00', '03', '2005/03/07', 3],
#  ['Estacion3', '3:30:00', '03', '2005/03/07', 3],
#  ['Estacion3', '3:40:00', '03', '2005/03/07', 3],
#  ['Estacion3', '3:50:00', '03', '2005/03/07', 3],
#  ['Estacion3', '4:00:00', '04', '2005/03/07', 3],
#  ['Estacion3', '4:10:00', '04', '2005/03/07', 3],
#  ['Estacion3', '4:20:00', '04', '2005/03/07', 3],
#  ['Estacion3', '4:30:00', '04', '2005/03/07', 3],
#  ['Estacion3', '4:40:00', '04', '2005/03/07', 3],
#  ['Estacion3', '4:50:00', '04', '2005/03/07', 3],
#  ['Estacion3', '5:00:00', '05', '2005/03/07', 3],
#  ['Estacion3', '5:10:00', '05', '2005/03/07', 3],
#  ['Estacion3', '5:20:00', '05', '2005/03/07', 3],
#  ['Estacion3', '5:30:00', '05', '2005/03/07', 3],
#  ['Estacion3', '5:40:00', '05', '2005/03/07', 3],
#  ['Estacion3', '5:50:00', '05', '2005/03/07', 3],
#  ['Estacion3', '6:00:00', '06', '2005/03/07', 3],
#  ['Estacion3', '6:10:00', '06', '2005/03/07', 3],
#  ['Estacion3', '6:20:00', '06', '2005/03/07', 3],
#  ['Estacion3', '6:30:00', '06', '2005/03/07', 3],
#  ['Estacion3', '6:40:00', '06', '2005/03/07', 3],
#  ['Estacion3', '6:50:00', '06', '2005/03/07', 3],
#  ['Estacion3', '7:00:00', '07', '2005/03/07', 3],
#  ['Estacion3', '7:10:00', '07', '2005/03/07', 3],
#  ['Estacion3', '7:20:00', '07', '2005/03/07', 3],
#  ['Estacion3', '7:30:00', '07', '2005/03/07', 3],
#  ['Estacion3', '7:40:00', '07', '2005/03/07', 3],
#  ['Estacion3', '7:50:00', '07', '2005/03/07', 3],
#  ['Estacion3', '8:00:00', '08', '2005/03/07', 3],
#  ['Estacion3', '8:10:00', '08', '2005/03/07', 3],
#  ['Estacion3', '8:20:00', '08', '2005/03/07', 3],
#  ['Estacion3', '8:30:00', '08', '2005/03/07', 3],
#  ['Estacion3', '8:40:00', '08', '2005/03/07', 3],
#  ['Estacion3', '8:50:00', '08', '2005/03/07', 3],
#  ['Estacion3', '10:00:00', '10', '2005/03/07', 3],
#  ['Estacion3', '10:10:00', '10', '2005/03/07', 3],
#  ['Estacion3', '10:20:00', '10', '2005/03/07', 3],
#  ['Estacion3', '10:30:00', '10', '2005/03/07', 3],
#  ['Estacion3', '10:40:00', '10', '2005/03/07', 3],
#  ['Estacion3', '10:50:00', '10', '2005/03/07', 3],
#  ['Estacion3', '11:00:00', '11', '2005/03/07', 3],
#  ['Estacion3', '11:10:00', '11', '2005/03/07', 3],
#  ['Estacion3', '11:20:00', '11', '2005/03/07', 3],
#  ['Estacion3', '11:30:00', '11', '2005/03/07', 3],
#  ['Estacion3', '11:40:00', '11', '2005/03/07', 3],
#  ['Estacion3', '11:50:00', '11', '2005/03/07', 3],
#  ['Estacion3', '12:00:00', '12', '2005/03/07', 3],
#  ['Estacion3', '12:10:00', '12', '2005/03/07', 3],
#  ['Estacion3', '12:20:00', '12', '2005/03/07', 3],
#  ['Estacion3', '12:30:00', '12', '2005/03/07', 3],
#  ['Estacion3', '12:40:00', '12', '2005/03/07', 3],
#  ['Estacion3', '12:50:00', '12', '2005/03/07', 3],
#  ['Estacion3', '13:00:00', '13', '2005/03/07', 3],
#  ['Estacion3', '13:10:00', '13', '2005/03/07', 3],
#  ['Estacion3', '13:20:00', '13', '2005/03/07', 3],
#  ['Estacion3', '13:30:00', '13', '2005/03/07', 3],
#  ['Estacion3', '13:40:00', '13', '2005/03/07', 3],
#  ['Estacion3', '13:50:00', '13', '2005/03/07', 3],
#  ['Estacion3', '14:00:00', '14', '2005/03/07', 3],
#  ['Estacion3', '14:10:00', '14', '2005/03/07', 3],
#  ['Estacion3', '14:20:00', '14', '2005/03/07', 3],
#  ['Estacion3', '14:30:00', '14', '2005/03/07', 3],
#  ['Estacion3', '14:40:00', '14', '2005/03/07', 3],
#  ['Estacion3', '14:50:00', '14', '2005/03/07', 3],
#  ['Estacion3', '15:00:00', '15', '2005/03/07', 3],
#  ['Estacion3', '15:10:00', '15', '2005/03/07', 3],
#  ['Estacion3', '15:20:00', '15', '2005/03/07', 3],
#  ['Estacion3', '15:30:00', '15', '2005/03/07', 3],
#  ['Estacion3', '15:40:00', '15', '2005/03/07', 3],
#  ['Estacion3', '15:50:00', '15', '2005/03/07', 3],
#  ['Estacion3', '16:00:00', '16', '2005/03/07', 3],
#  ['Estacion3', '16:10:00', '16', '2005/03/07', 3],
#  ['Estacion3', '16:20:00', '16', '2005/03/07', 3],
#  ['Estacion3', '16:30:00', '16', '2005/03/07', 3],
#  ['Estacion3', '16:40:00', '16', '2005/03/07', 3],
#  ['Estacion3', '16:50:00', '16', '2005/03/07', 3],
#  ['Estacion3', '17:00:00', '17', '2005/03/07', 3],
#  ['Estacion3', '17:10:00', '17', '2005/03/07', 3],
#  ['Estacion3', '17:20:00', '17', '2005/03/07', 3],
#  ['Estacion3', '17:30:00', '17', '2005/03/07', 3],
#  ['Estacion3', '17:40:00', '17', '2005/03/07', 3],
#  ['Estacion3', '17:50:00', '17', '2005/03/07', 3],
#  ['Estacion3', '18:00:00', '18', '2005/03/07', 3],
#  ['Estacion3', '18:10:00', '18', '2005/03/07', 3],
#  ['Estacion3', '18:20:00', '18', '2005/03/07', 3],
#  ['Estacion3', '18:30:00', '18', '2005/03/07', 3],
#  ['Estacion3', '18:40:00', '18', '2005/03/07', 3],
#  ['Estacion3', '18:50:00', '18', '2005/03/07', 3],
#  ['Estacion3', '19:00:00', '19', '2005/03/07', 3],
#  ['Estacion3', '19:10:00', '19', '2005/03/07', 3],
#  ['Estacion3', '19:20:00', '19', '2005/03/07', 3],
#  ['Estacion3', '19:30:00', '19', '2005/03/07', 3],
#  ['Estacion3', '19:40:00', '19', '2005/03/07', 3],
#  ['Estacion3', '19:50:00', '19', '2005/03/07', 3],
#  ['Estacion3', '20:00:00', '20', '2005/03/07', 3],
#  ['Estacion3', '20:10:00', '20', '2005/03/07', 3],
#  ['Estacion3', '20:20:00', '20', '2005/03/07', 3],
#  ['Estacion3', '20:30:00', '20', '2005/03/07', 3],
#  ['Estacion3', '20:40:00', '20', '2005/03/07', 3],
#  ['Estacion3', '20:50:00', '20', '2005/03/07', 3],
#  ['Estacion3', '21:00:00', '21', '2005/03/07', 3],
#  ['Estacion3', '21:10:00', '21', '2005/03/07', 3],
#  ['Estacion3', '21:20:00', '21', '2005/03/07', 3],
#  ['Estacion3', '21:30:00', '21', '2005/03/07', 3],
#  ['Estacion3', '21:40:00', '21', '2005/03/07', 3],
#  ['Estacion3', '21:50:00', '21', '2005/03/07', 3],
#  ['Estacion3', '22:00:00', '22', '2005/03/07', 3],
#  ['Estacion3', '22:10:00', '22', '2005/03/07', 3],
#  ['Estacion3', '22:20:00', '22', '2005/03/07', 3],
#  ['Estacion3', '22:30:00', '22', '2005/03/07', 3],
#  ['Estacion3', '22:40:00', '22', '2005/03/07', 3],
#  ['Estacion3', '22:50:00', '22', '2005/03/07', 3],
#  ['Estacion3', '23:00:00', '23', '2005/03/07', 3],
#  ['Estacion3', '23:10:00', '23', '2005/03/07', 3],
#  ['Estacion3', '23:20:00', '23', '2005/03/07', 3],
#  ['Estacion3', '23:30:00', '23', '2005/03/07', 3],
#  ['Estacion3', '23:40:00', '23', '2005/03/07', 3],
#  ['Estacion3', '23:50:00', '23', '2005/03/07', 3],
#  ['Estacion3', '0:00:00', '00', '2005/03/08', 3],
#  ['Estacion3', '0:10:00', '00', '2005/03/08', 3],
#  ['Estacion3', '0:20:00', '00', '2005/03/08', 3],
#  ['Estacion3', '0:30:00', '00', '2005/03/08', 3],
#  ['Estacion3', '0:40:00', '00', '2005/03/08', 3],
#  ['Estacion3', '0:50:00', '00', '2005/03/08', 3],
#  ['Estacion3', '1:00:00', '01', '2005/03/08', 3],
#  ['Estacion3', '1:10:00', '01', '2005/03/08', 3],
#  ['Estacion3', '1:20:00', '01', '2005/03/08', 3],
#  ['Estacion3', '1:30:00', '01', '2005/03/08', 3],
#  ['Estacion3', '1:40:00', '01', '2005/03/08', 3],
#  ['Estacion3', '1:50:00', '01', '2005/03/08', 3],
#  ['Estacion3', '2:00:00', '02', '2005/03/08', 3],
#  ['Estacion3', '2:10:00', '02', '2005/03/08', 3],
#  ['Estacion3', '2:20:00', '02', '2005/03/08', 3],
#  ['Estacion3', '2:30:00', '02', '2005/03/08', 3],
#  ['Estacion3', '2:40:00', '02', '2005/03/08', 3],
#  ['Estacion3', '2:50:00', '02', '2005/03/08', 3],
#  ['Estacion3', '3:00:00', '03', '2005/03/08', 3],
#  ['Estacion3', '3:10:00', '03', '2005/03/08', 3],
#  ['Estacion3', '3:20:00', '03', '2005/03/08', 3],
#  ['Estacion3', '3:30:00', '03', '2005/03/08', 3],
#  ['Estacion3', '3:40:00', '03', '2005/03/08', 3],
#  ['Estacion3', '3:50:00', '03', '2005/03/08', 3],
#  ['Estacion3', '4:00:00', '04', '2005/03/08', 3],
#  ['Estacion3', '4:10:00', '04', '2005/03/08', 3],
#  ['Estacion3', '4:20:00', '04', '2005/03/08', 3],
#  ['Estacion3', '4:30:00', '04', '2005/03/08', 3],
#  ['Estacion3', '4:40:00', '04', '2005/03/08', 3],
#  ['Estacion3', '4:50:00', '04', '2005/03/08', 3],
#  ['Estacion3', '5:00:00', '05', '2005/03/08', 3],
#  ['Estacion3', '5:10:00', '05', '2005/03/08', 3],
#  ['Estacion3', '5:20:00', '05', '2005/03/08', 3],
#  ['Estacion3', '5:30:00', '05', '2005/03/08', 3],
#  ['Estacion3', '5:40:00', '05', '2005/03/08', 3],
#  ['Estacion3', '5:50:00', '05', '2005/03/08', 3],
#  ['Estacion3', '6:00:00', '06', '2005/03/08', 3],
#  ['Estacion3', '6:10:00', '06', '2005/03/08', 3],
#  ['Estacion3', '6:20:00', '06', '2005/03/08', 3],
#  ['Estacion3', '6:30:00', '06', '2005/03/08', 3],
#  ['Estacion3', '6:40:00', '06', '2005/03/08', 3],
#  ['Estacion3', '6:50:00', '06', '2005/03/08', 3],
#  ['Estacion3', '7:00:00', '07', '2005/03/08', 3],
#  ['Estacion3', '7:10:00', '07', '2005/03/08', 3],
#  ['Estacion3', '7:20:00', '07', '2005/03/08', 3],
#  ['Estacion3', '7:30:00', '07', '2005/03/08', 3],
#  ['Estacion3', '7:40:00', '07', '2005/03/08', 3],
#  ['Estacion3', '7:50:00', '07', '2005/03/08', 3],
#  ['Estacion3', '8:00:00', '08', '2005/03/08', 3],
#  ['Estacion3', '8:10:00', '08', '2005/03/08', 3],
#  ['Estacion3', '8:20:00', '08', '2005/03/08', 3],
#  ['Estacion3', '8:30:00', '08', '2005/03/08', 3],
#  ['Estacion3', '8:40:00', '08', '2005/03/08', 3],
#  ['Estacion3', '8:50:00', '08', '2005/03/08', 3],
#  ['Estacion3', '9:00:00', '09', '2005/03/08', 3],
#  ['Estacion3', '9:10:00', '09', '2005/03/08', 3],
#  ['Estacion3', '9:20:00', '09', '2005/03/08', 3],
#  ['Estacion3', '9:30:00', '09', '2005/03/08', 3],
#  ['Estacion3', '9:40:00', '09', '2005/03/08', 3],
#  ['Estacion3', '9:50:00', '09', '2005/03/08', 3],
#  ['Estacion3', '10:00:00', '10', '2005/03/08', 3],
#  ['Estacion3', '10:10:00', '10', '2005/03/08', 3],
#  ['Estacion3', '10:20:00', '10', '2005/03/08', 3],
#  ['Estacion3', '10:30:00', '10', '2005/03/08', 3],
#  ['Estacion3', '10:40:00', '10', '2005/03/08', 3],
#  ['Estacion3', '10:50:00', '10', '2005/03/08', 3],
#  ['Estacion3', '11:00:00', '11', '2005/03/08', 3],
#  ['Estacion3', '11:10:00', '11', '2005/03/08', 3],
#  ['Estacion3', '11:20:00', '11', '2005/03/08', 3],
#  ['Estacion3', '11:30:00', '11', '2005/03/08', 3],
#  ['Estacion3', '11:40:00', '11', '2005/03/08', 3],
#  ['Estacion3', '11:50:00', '11', '2005/03/08', 3],
#  ['Estacion3', '12:00:00', '12', '2005/03/08', 3],
#  ['Estacion3', '12:10:00', '12', '2005/03/08', 3],
#  ['Estacion3', '12:20:00', '12', '2005/03/08', 3],
#  ['Estacion3', '12:30:00', '12', '2005/03/08', 3],
#  ['Estacion3', '12:40:00', '12', '2005/03/08', 3],
#  ['Estacion3', '12:50:00', '12', '2005/03/08', 3],
#  ['Estacion3', '13:00:00', '13', '2005/03/08', 3],
#  ['Estacion3', '13:10:00', '13', '2005/03/08', 3],
#  ['Estacion3', '13:20:00', '13', '2005/03/08', 3],
#  ['Estacion3', '13:30:00', '13', '2005/03/08', 3],
#  ['Estacion3', '13:40:00', '13', '2005/03/08', 3],
#  ['Estacion3', '13:50:00', '13', '2005/03/08', 3],
#  ['Estacion3', '14:00:00', '14', '2005/03/08', 3],
#  ['Estacion3', '14:10:00', '14', '2005/03/08', 3],
#  ['Estacion3', '14:20:00', '14', '2005/03/08', 3],
#  ['Estacion3', '14:30:00', '14', '2005/03/08', 3],
#  ['Estacion3', '14:40:00', '14', '2005/03/08', 3],
#  ['Estacion3', '14:50:00', '14', '2005/03/08', 3],
#  ['Estacion3', '15:00:00', '15', '2005/03/08', 3],
#  ['Estacion3', '15:10:00', '15', '2005/03/08', 3],
#  ['Estacion3', '15:20:00', '15', '2005/03/08', 3],
#  ['Estacion3', '15:30:00', '15', '2005/03/08', 3],
#  ['Estacion3', '15:40:00', '15', '2005/03/08', 3],
#  ['Estacion3', '15:50:00', '15', '2005/03/08', 3],
#  ['Estacion3', '16:00:00', '16', '2005/03/08', 3],
#  ['Estacion3', '16:10:00', '16', '2005/03/08', 3],
#  ['Estacion3', '16:20:00', '16', '2005/03/08', 3],
#  ['Estacion3', '16:30:00', '16', '2005/03/08', 3],
#  ['Estacion3', '16:40:00', '16', '2005/03/08', 3],
#  ['Estacion3', '16:50:00', '16', '2005/03/08', 3],
#  ['Estacion3', '17:00:00', '17', '2005/03/08', 3],
#  ['Estacion3', '17:10:00', '17', '2005/03/08', 3],
#  ['Estacion3', '17:20:00', '17', '2005/03/08', 3],
#  ['Estacion3', '17:30:00', '17', '2005/03/08', 3],
#  ['Estacion3', '17:40:00', '17', '2005/03/08', 3],
#  ['Estacion3', '17:50:00', '17', '2005/03/08', 3],
#  ['Estacion3', '18:00:00', '18', '2005/03/08', 3],
#  ['Estacion3', '18:10:00', '18', '2005/03/08', 3],
#  ['Estacion3', '18:20:00', '18', '2005/03/08', 3],
#  ['Estacion3', '18:30:00', '18', '2005/03/08', 3],
#  ['Estacion3', '18:40:00', '18', '2005/03/08', 3],
#  ['Estacion3', '18:50:00', '18', '2005/03/08', 3],
#  ['Estacion3', '19:00:00', '19', '2005/03/08', 3],
#  ['Estacion3', '19:10:00', '19', '2005/03/08', 3],
#  ['Estacion3', '19:20:00', '19', '2005/03/08', 3],
#  ['Estacion3', '19:30:00', '19', '2005/03/08', 3],
#  ['Estacion3', '19:40:00', '19', '2005/03/08', 3],
#  ['Estacion3', '19:50:00', '19', '2005/03/08', 3],
#  ['Estacion3', '20:00:00', '20', '2005/03/08', 3],
#  ['Estacion3', '20:10:00', '20', '2005/03/08', 3],
#  ['Estacion3', '20:20:00', '20', '2005/03/08', 3],
#  ['Estacion3', '20:30:00', '20', '2005/03/08', 3],
#  ['Estacion3', '20:40:00', '20', '2005/03/08', 3],
#  ['Estacion3', '20:50:00', '20', '2005/03/08', 3],
#  ['Estacion3', '21:00:00', '21', '2005/03/08', 3],
#  ['Estacion3', '21:10:00', '21', '2005/03/08', 3],
#  ['Estacion3', '21:20:00', '21', '2005/03/08', 3],
#  ['Estacion3', '21:30:00', '21', '2005/03/08', 3],
#  ['Estacion3', '21:40:00', '21', '2005/03/08', 3],
#  ['Estacion3', '21:50:00', '21', '2005/03/08', 3],
#  ['Estacion3', '23:00:00', '23', '2005/03/08', 3],
#  ['Estacion3', '23:10:00', '23', '2005/03/08', 3],
#  ['Estacion3', '23:20:00', '23', '2005/03/08', 3],
#  ['Estacion3', '23:30:00', '23', '2005/03/08', 3],
#  ['Estacion3', '23:40:00', '23', '2005/03/08', 3],
#  ['Estacion3', '23:50:00', '23', '2005/03/08', 3],
#  ['Estacion3', '0:00:00', '00', '2005/03/09', 3],
#  ['Estacion3', '0:10:00', '00', '2005/03/09', 3],
#  ['Estacion3', '0:20:00', '00', '2005/03/09', 3],
#  ['Estacion3', '0:30:00', '00', '2005/03/09', 3],
#  ['Estacion3', '0:40:00', '00', '2005/03/09', 3],
#  ['Estacion3', '0:50:00', '00', '2005/03/09', 3],
#  ['Estacion3', '1:00:00', '01', '2005/03/09', 3],
#  ['Estacion3', '1:10:00', '01', '2005/03/09', 3],
#  ['Estacion3', '1:20:00', '01', '2005/03/09', 3],
#  ['Estacion3', '1:30:00', '01', '2005/03/09', 3],
#  ['Estacion3', '1:40:00', '01', '2005/03/09', 3],
#  ['Estacion3', '1:50:00', '01', '2005/03/09', 3],
#  ['Estacion3', '2:00:00', '02', '2005/03/09', 3],
#  ['Estacion3', '2:10:00', '02', '2005/03/09', 3],
#  ['Estacion3', '2:20:00', '02', '2005/03/09', 3],
#  ['Estacion3', '2:30:00', '02', '2005/03/09', 3],
#  ['Estacion3', '2:40:00', '02', '2005/03/09', 3],
#  ['Estacion3', '2:50:00', '02', '2005/03/09', 3],
#  ['Estacion3', '3:00:00', '03', '2005/03/09', 3],
#  ['Estacion3', '3:10:00', '03', '2005/03/09', 3],
#  ['Estacion3', '3:20:00', '03', '2005/03/09', 3],
#  ['Estacion3', '3:30:00', '03', '2005/03/09', 3],
#  ['Estacion3', '3:40:00', '03', '2005/03/09', 3],
#  ['Estacion3', '3:50:00', '03', '2005/03/09', 3],
#  ['Estacion3', '4:00:00', '04', '2005/03/09', 3],
#  ['Estacion3', '4:10:00', '04', '2005/03/09', 3],
#  ['Estacion3', '4:20:00', '04', '2005/03/09', 3],
#  ['Estacion3', '4:30:00', '04', '2005/03/09', 3],
#  ['Estacion3', '4:40:00', '04', '2005/03/09', 3],
#  ['Estacion3', '4:50:00', '04', '2005/03/09', 3],
#  ['Estacion3', '5:00:00', '05', '2005/03/09', 3],
#  ['Estacion3', '5:10:00', '05', '2005/03/09', 3],
#  ['Estacion3', '5:20:00', '05', '2005/03/09', 3],
#  ['Estacion3', '5:30:00', '05', '2005/03/09', 3],
#  ['Estacion3', '5:40:00', '05', '2005/03/09', 3],
#  ['Estacion3', '5:50:00', '05', '2005/03/09', 3],
#  ['Estacion3', '6:00:00', '06', '2005/03/09', 3],
#  ['Estacion3', '6:10:00', '06', '2005/03/09', 3],
#  ['Estacion3', '6:20:00', '06', '2005/03/09', 3],
#  ['Estacion3', '6:30:00', '06', '2005/03/09', 3],
#  ['Estacion3', '6:40:00', '06', '2005/03/09', 3],
#  ['Estacion3', '6:50:00', '06', '2005/03/09', 3],
#  ['Estacion3', '7:00:00', '07', '2005/03/09', 3],
#  ['Estacion3', '7:10:00', '07', '2005/03/09', 3],
#  ['Estacion3', '7:20:00', '07', '2005/03/09', 3],
#  ['Estacion3', '7:30:00', '07', '2005/03/09', 3],
#  ['Estacion3', '7:40:00', '07', '2005/03/09', 3],
#  ['Estacion3', '7:50:00', '07', '2005/03/09', 3],
#  ['Estacion3', '8:00:00', '08', '2005/03/09', 3],
#  ['Estacion3', '8:10:00', '08', '2005/03/09', 3],
#  ['Estacion3', '8:20:00', '08', '2005/03/09', 3],
#  ['Estacion3', '8:30:00', '08', '2005/03/09', 3],
#  ['Estacion3', '8:40:00', '08', '2005/03/09', 3],
#  ['Estacion3', '8:50:00', '08', '2005/03/09', 3],
#  ['Estacion3', '9:00:00', '09', '2005/03/09', 3],
#  ['Estacion3', '9:10:00', '09', '2005/03/09', 3],
#  ['Estacion3', '9:20:00', '09', '2005/03/09', 3],
#  ['Estacion3', '9:30:00', '09', '2005/03/09', 3],
#  ['Estacion3', '9:40:00', '09', '2005/03/09', 3],
#  ['Estacion3', '9:50:00', '09', '2005/03/09', 3],
#  ['Estacion3', '11:00:00', '11', '2005/03/09', 3],
#  ['Estacion3', '11:10:00', '11', '2005/03/09', 3],
#  ['Estacion3', '11:20:00', '11', '2005/03/09', 3],
#  ['Estacion3', '11:30:00', '11', '2005/03/09', 3],
#  ['Estacion3', '11:40:00', '11', '2005/03/09', 3],
#  ['Estacion3', '11:50:00', '11', '2005/03/09', 3],
#  ['Estacion3', '12:00:00', '12', '2005/03/09', 3],
#  ['Estacion3', '12:10:00', '12', '2005/03/09', 3],
#  ['Estacion3', '12:20:00', '12', '2005/03/09', 3],
#  ['Estacion3', '12:30:00', '12', '2005/03/09', 3],
#  ['Estacion3', '12:40:00', '12', '2005/03/09', 3],
#  ['Estacion3', '12:50:00', '12', '2005/03/09', 3],
#  ['Estacion3', '13:00:00', '13', '2005/03/09', 3],
#  ['Estacion3', '13:10:00', '13', '2005/03/09', 3],
#  ['Estacion3', '13:20:00', '13', '2005/03/09', 3],
#  ['Estacion3', '13:30:00', '13', '2005/03/09', 3],
#  ['Estacion3', '13:40:00', '13', '2005/03/09', 3],
#  ['Estacion3', '13:50:00', '13', '2005/03/09', 3],
#  ['Estacion3', '14:00:00', '14', '2005/03/10', 3],
#  ['Estacion3', '14:10:00', '14', '2005/03/10', 3],
#  ['Estacion3', '14:20:00', '14', '2005/03/10', 3],
#  ['Estacion3', '14:30:00', '14', '2005/03/10', 3],
#  ['Estacion3', '14:40:00', '14', '2005/03/10', 3],
#  ['Estacion3', '14:50:00', '14', '2005/03/10', 3],
#  ['Estacion3', '15:00:00', '15', '2005/03/10', 3],
#  ['Estacion3', '15:10:00', '15', '2005/03/10', 3],
#  ['Estacion3', '15:20:00', '15', '2005/03/10', 3],
#  ['Estacion3', '15:30:00', '15', '2005/03/10', 3],
#  ['Estacion3', '15:40:00', '15', '2005/03/10', 3],
#  ['Estacion3', '15:50:00', '15', '2005/03/10', 3],
#  ['Estacion3', '16:00:00', '16', '2005/03/10', 3],
#  ['Estacion3', '16:10:00', '16', '2005/03/10', 3],
#  ['Estacion3', '16:20:00', '16', '2005/03/10', 3],
#  ['Estacion3', '16:30:00', '16', '2005/03/10', 3],
#  ['Estacion3', '16:40:00', '16', '2005/03/10', 3],
#  ['Estacion3', '16:50:00', '16', '2005/03/10', 3],
#  ['Estacion3', '17:00:00', '17', '2005/03/10', 3],
#  ['Estacion3', '17:10:00', '17', '2005/03/10', 3],
#  ['Estacion3', '17:20:00', '17', '2005/03/10', 3],
#  ['Estacion3', '17:30:00', '17', '2005/03/10', 3],
#  ['Estacion3', '17:40:00', '17', '2005/03/10', 3],
#  ['Estacion3', '17:50:00', '17', '2005/03/10', 3],
#  ['Estacion3', '18:00:00', '18', '2005/03/10', 3],
#  ['Estacion3', '18:10:00', '18', '2005/03/10', 3],
#  ['Estacion3', '18:20:00', '18', '2005/03/10', 3],
#  ['Estacion3', '18:30:00', '18', '2005/03/10', 3],
#  ['Estacion3', '18:40:00', '18', '2005/03/10', 3],
#  ['Estacion3', '18:50:00', '18', '2005/03/10', 3],
#  ['Estacion3', '19:00:00', '19', '2005/03/10', 3],
#  ['Estacion3', '19:10:00', '19', '2005/03/10', 3],
#  ['Estacion3', '19:20:00', '19', '2005/03/10', 3],
#  ['Estacion3', '19:30:00', '19', '2005/03/10', 3],
#  ['Estacion3', '19:40:00', '19', '2005/03/10', 3],
#  ['Estacion3', '19:50:00', '19', '2005/03/10', 3],
#  ['Estacion3', '20:00:00', '20', '2005/03/10', 3],
#  ['Estacion3', '20:10:00', '20', '2005/03/10', 3],
#  ['Estacion3', '20:20:00', '20', '2005/03/10', 3],
#  ['Estacion3', '20:30:00', '20', '2005/03/10', 3],
#  ['Estacion3', '20:40:00', '20', '2005/03/10', 3],
#  ['Estacion3', '20:50:00', '20', '2005/03/10', 3],
#  ['Estacion3', '22:00:00', '22', '2005/03/10', 3],
#  ['Estacion3', '22:10:00', '22', '2005/03/10', 3],
#  ['Estacion3', '22:20:00', '22', '2005/03/10', 3],
#  ['Estacion3', '22:30:00', '22', '2005/03/10', 3],
#  ['Estacion3', '22:40:00', '22', '2005/03/10', 3],
#  ['Estacion3', '22:50:00', '22', '2005/03/10', 3],
#  ['Estacion3', '23:00:00', '23', '2005/03/10', 3],
#  ['Estacion3', '23:10:00', '23', '2005/03/10', 3],
#  ['Estacion3', '23:20:00', '23', '2005/03/10', 3],
#  ['Estacion3', '23:30:00', '23', '2005/03/10', 3],
#  ['Estacion3', '23:40:00', '23', '2005/03/10', 3],
#  ['Estacion3', '23:50:00', '23', '2005/03/10', 3],
#  ['Estacion3', '0:00:00', '00', '2005/03/11', 3],
#  ['Estacion3', '0:10:00', '00', '2005/03/11', 3],
#  ['Estacion3', '0:20:00', '00', '2005/03/11', 3],
#  ['Estacion3', '0:30:00', '00', '2005/03/11', 3],
#  ['Estacion3', '0:40:00', '00', '2005/03/11', 3],
#  ['Estacion3', '0:50:00', '00', '2005/03/11', 3],
#  ['Estacion3', '1:00:00', '01', '2005/03/11', 3],
#  ['Estacion3', '1:10:00', '01', '2005/03/11', 3],
#  ['Estacion3', '1:20:00', '01', '2005/03/11', 3],
#  ['Estacion3', '1:30:00', '01', '2005/03/11', 3],
#  ['Estacion3', '1:40:00', '01', '2005/03/11', 3],
#  ['Estacion3', '1:50:00', '01', '2005/03/11', 3],
#  ['Estacion3', '2:00:00', '02', '2005/03/11', 3],
#  ['Estacion3', '2:10:00', '02', '2005/03/11', 3],
#  ['Estacion3', '2:20:00', '02', '2005/03/11', 3],
#  ['Estacion3', '2:30:00', '02', '2005/03/11', 3],
#  ['Estacion3', '2:40:00', '02', '2005/03/11', 3],
#  ['Estacion3', '2:50:00', '02', '2005/03/11', 3],
#  ['Estacion3', '3:00:00', '03', '2005/03/11', 3],
#  ['Estacion3', '3:10:00', '03', '2005/03/11', 3],
#  ['Estacion3', '3:20:00', '03', '2005/03/11', 3],
#  ['Estacion3', '3:30:00', '03', '2005/03/11', 3],
#  ['Estacion3', '3:40:00', '03', '2005/03/11', 3],
#  ['Estacion3', '3:50:00', '03', '2005/03/11', 3],
#  ['Estacion3', '4:00:00', '04', '2005/03/11', 3],
#  ['Estacion3', '4:10:00', '04', '2005/03/11', 3],
#  ['Estacion3', '4:20:00', '04', '2005/03/11', 3],
#  ['Estacion3', '4:30:00', '04', '2005/03/11', 3],
#  ['Estacion3', '4:40:00', '04', '2005/03/11', 3],
#  ['Estacion3', '4:50:00', '04', '2005/03/11', 3],
#  ['Estacion3', '5:00:00', '05', '2005/03/11', 3],
#  ['Estacion3', '5:10:00', '05', '2005/03/11', 3],
#  ['Estacion3', '5:20:00', '05', '2005/03/11', 3],
#  ['Estacion3', '5:30:00', '05', '2005/03/11', 3],
#  ['Estacion3', '5:40:00', '05', '2005/03/11', 3],
#  ['Estacion3', '5:50:00', '05', '2005/03/11', 3],
#  ['Estacion3', '6:00:00', '06', '2005/03/11', 3],
#  ['Estacion3', '6:10:00', '06', '2005/03/11', 3],
#  ['Estacion3', '6:20:00', '06', '2005/03/11', 3],
#  ['Estacion3', '6:30:00', '06', '2005/03/11', 3],
#  ['Estacion3', '6:40:00', '06', '2005/03/11', 3],
#  ['Estacion3', '6:50:00', '06', '2005/03/11', 3],
#  ['Estacion3', '7:00:00', '07', '2005/03/11', 3],
#  ['Estacion3', '7:10:00', '07', '2005/03/11', 3],
#  ['Estacion3', '7:20:00', '07', '2005/03/11', 3],
#  ['Estacion3', '7:30:00', '07', '2005/03/11', 3],
#  ['Estacion3', '7:40:00', '07', '2005/03/11', 3],
#  ['Estacion3', '7:50:00', '07', '2005/03/11', 3],
#  ['Estacion3', '8:00:00', '08', '2005/03/11', 3],
#  ['Estacion3', '8:10:00', '08', '2005/03/11', 3],
#  ['Estacion3', '8:20:00', '08', '2005/03/11', 3],
#  ['Estacion3', '8:30:00', '08', '2005/03/11', 3],
#  ['Estacion3', '8:40:00', '08', '2005/03/11', 3],
#  ['Estacion3', '8:50:00', '08', '2005/03/11', 3],
#  ['Estacion3', '9:00:00', '09', '2005/03/11', 3],
#  ['Estacion3', '9:10:00', '09', '2005/03/11', 3],
#  ['Estacion3', '9:20:00', '09', '2005/03/11', 3],
#  ['Estacion3', '9:30:00', '09', '2005/03/11', 3],
#  ['Estacion3', '9:40:00', '09', '2005/03/11', 3],
#  ['Estacion3', '9:50:00', '09', '2005/03/11', 3],
#  ['Estacion3', '10:00:00', '10', '2005/03/11', 3],
#  ['Estacion3', '10:10:00', '10', '2005/03/11', 3],
#  ['Estacion3', '10:20:00', '10', '2005/03/11', 3],
#  ['Estacion3', '10:30:00', '10', '2005/03/11', 3],
#  ['Estacion3', '10:40:00', '10', '2005/03/11', 3],
#  ['Estacion3', '10:50:00', '10', '2005/03/11', 3],
#  ['Estacion3', '11:00:00', '11', '2005/03/11', 3],
#  ['Estacion3', '11:10:00', '11', '2005/03/11', 3],
#  ['Estacion3', '11:20:00', '11', '2005/03/11', 3],
#  ['Estacion3', '11:30:00', '11', '2005/03/11', 3],
#  ['Estacion3', '11:40:00', '11', '2005/03/11', 3],
#  ['Estacion3', '11:50:00', '11', '2005/03/11', 3],
#  ['Estacion3', '12:00:00', '12', '2005/03/11', 3],
#  ['Estacion3', '12:10:00', '12', '2005/03/11', 3],
#  ['Estacion3', '12:20:00', '12', '2005/03/11', 3],
#  ['Estacion3', '12:30:00', '12', '2005/03/11', 3],
#  ['Estacion3', '12:40:00', '12', '2005/03/11', 3],
#  ['Estacion3', '12:50:00', '12', '2005/03/11', 3],
#  ['Estacion3', '13:00:00', '13', '2005/03/11', 3],
#  ['Estacion3', '13:10:00', '13', '2005/03/11', 3],
#  ['Estacion3', '13:20:00', '13', '2005/03/11', 3],
#  ['Estacion3', '13:30:00', '13', '2005/03/11', 3],
#  ['Estacion3', '13:40:00', '13', '2005/03/11', 3],
#  ['Estacion3', '13:50:00', '13', '2005/03/11', 3],
#  ['Estacion3', '14:00:00', '14', '2005/03/11', 3],
#  ['Estacion3', '14:10:00', '14', '2005/03/11', 3],
#  ['Estacion3', '14:20:00', '14', '2005/03/11', 3],
#  ['Estacion3', '14:30:00', '14', '2005/03/11', 3],
#  ['Estacion3', '14:40:00', '14', '2005/03/11', 3],
#  ['Estacion3', '14:50:00', '14', '2005/03/11', 3],
#  ['Estacion3', '15:00:00', '15', '2005/03/11', 3],
#  ['Estacion3', '15:10:00', '15', '2005/03/11', 3],
#  ['Estacion3', '15:20:00', '15', '2005/03/11', 3],
#  ['Estacion3', '15:30:00', '15', '2005/03/11', 3],
#  ['Estacion3', '15:40:00', '15', '2005/03/11', 3],
#  ['Estacion3', '15:50:00', '15', '2005/03/11', 3],
#  ['Estacion3', '16:00:00', '16', '2005/03/11', 3],
#  ['Estacion3', '16:10:00', '16', '2005/03/11', 3],
#  ['Estacion3', '16:20:00', '16', '2005/03/11', 3],
#  ['Estacion3', '16:30:00', '16', '2005/03/11', 3],
#  ['Estacion3', '16:40:00', '16', '2005/03/11', 3],
#  ['Estacion3', '16:50:00', '16', '2005/03/11', 3],
#  ['Estacion3', '17:00:00', '17', '2005/03/11', 3],
#  ['Estacion3', '17:10:00', '17', '2005/03/11', 3],
#  ['Estacion3', '17:20:00', '17', '2005/03/11', 3],
#  ['Estacion3', '17:30:00', '17', '2005/03/11', 3],
#  ['Estacion3', '17:40:00', '17', '2005/03/11', 3],
#  ['Estacion3', '17:50:00', '17', '2005/03/11', 3],
#  ['Estacion3', '18:00:00', '18', '2005/03/11', 3],
#  ['Estacion3', '18:10:00', '18', '2005/03/11', 3],
#  ['Estacion3', '18:20:00', '18', '2005/03/11', 3],
#  ['Estacion3', '18:30:00', '18', '2005/03/11', 3],
#  ['Estacion3', '18:40:00', '18', '2005/03/11', 3],
#  ['Estacion3', '18:50:00', '18', '2005/03/11', 3],
#  ['Estacion3', '19:00:00', '19', '2005/03/11', 3],
#  ['Estacion3', '19:10:00', '19', '2005/03/11', 3],
#  ['Estacion3', '19:20:00', '19', '2005/03/11', 3],
#  ['Estacion3', '19:30:00', '19', '2005/03/11', 3],
#  ['Estacion3', '19:40:00', '19', '2005/03/11', 3],
#  ['Estacion3', '19:50:00', '19', '2005/03/11', 3],
#  ['Estacion3', '20:00:00', '20', '2005/03/11', 3],
#  ['Estacion3', '20:10:00', '20', '2005/03/11', 3],
#  ['Estacion3', '20:20:00', '20', '2005/03/11', 3],
#  ['Estacion3', '20:30:00', '20', '2005/03/11', 3],
#  ['Estacion3', '20:40:00', '20', '2005/03/11', 3],
#  ['Estacion3', '20:50:00', '20', '2005/03/11', 3],
#  ['Estacion3', '21:00:00', '21', '2005/03/11', 3],
#  ['Estacion3', '21:10:00', '21', '2005/03/11', 3],
#  ['Estacion3', '21:20:00', '21', '2005/03/11', 3],
#  ['Estacion3', '21:30:00', '21', '2005/03/11', 3],
#  ['Estacion3', '21:40:00', '21', '2005/03/11', 3],
#  ['Estacion3', '21:50:00', '21', '2005/03/11', 3],
#  ['Estacion3', '22:00:00', '22', '2005/03/11', 3],
#  ['Estacion3', '22:10:00', '22', '2005/03/11', 3],
#  ['Estacion3', '22:20:00', '22', '2005/03/11', 3],
#  ['Estacion3', '22:30:00', '22', '2005/03/11', 3],
#  ['Estacion3', '22:40:00', '22', '2005/03/11', 3],
#  ['Estacion3', '22:50:00', '22', '2005/03/11', 3],
#  ['Estacion3', '23:00:00', '23', '2005/03/11', 3],
#  ['Estacion3', '23:10:00', '23', '2005/03/11', 3],
#  ['Estacion3', '23:20:00', '23', '2005/03/11', 3],
#  ['Estacion3', '23:30:00', '23', '2005/03/11', 3],
#  ['Estacion3', '23:40:00', '23', '2005/03/11', 3],
#  ['Estacion3', '23:50:00', '23', '2005/03/11', 3],
#  ['Estacion3', '0:00:00', '00', '2005/03/12', 3],
#  ['Estacion3', '0:10:00', '00', '2005/03/12', 3],
#  ['Estacion3', '0:20:00', '00', '2005/03/12', 3],
#  ['Estacion3', '0:30:00', '00', '2005/03/12', 3],
#  ['Estacion3', '0:40:00', '00', '2005/03/12', 3],
#  ['Estacion3', '0:50:00', '00', '2005/03/12', 3],
#  ['Estacion3', '1:00:00', '01', '2005/03/12', 3],
#  ['Estacion3', '1:10:00', '01', '2005/03/12', 3],
#  ['Estacion3', '1:20:00', '01', '2005/03/12', 3],
#  ['Estacion3', '1:30:00', '01', '2005/03/12', 3],
#  ['Estacion3', '1:40:00', '01', '2005/03/12', 3],
#  ['Estacion3', '1:50:00', '01', '2005/03/12', 3],
#  ['Estacion3', '2:00:00', '02', '2005/03/12', 3],
#  ['Estacion3', '2:10:00', '02', '2005/03/12', 3],
#  ['Estacion3', '2:20:00', '02', '2005/03/12', 3],
#  ['Estacion3', '2:30:00', '02', '2005/03/12', 3],
#  ['Estacion3', '2:40:00', '02', '2005/03/12', 3],
#  ['Estacion3', '2:50:00', '02', '2005/03/12', 3],
#  ['Estacion3', '4:00:00', '04', '2005/03/12', 3],
#  ['Estacion3', '4:10:00', '04', '2005/03/12', 3],
#  ['Estacion3', '4:20:00', '04', '2005/03/12', 3],
#  ['Estacion3', '4:30:00', '04', '2005/03/12', 3],
#  ['Estacion3', '4:40:00', '04', '2005/03/12', 3],
#  ['Estacion3', '4:50:00', '04', '2005/03/12', 3],
#  ['Estacion3', '5:00:00', '05', '2005/03/12', 3],
#  ['Estacion3', '5:10:00', '05', '2005/03/12', 3],
#  ['Estacion3', '5:20:00', '05', '2005/03/12', 3],
#  ['Estacion3', '5:30:00', '05', '2005/03/12', 3],
#  ['Estacion3', '5:40:00', '05', '2005/03/12', 3],
#  ['Estacion3', '5:50:00', '05', '2005/03/12', 3],
#  ['Estacion3', '6:00:00', '06', '2005/03/12', 3],
#  ['Estacion3', '6:10:00', '06', '2005/03/12', 3],
#  ['Estacion3', '6:20:00', '06', '2005/03/12', 3],
#  ['Estacion3', '6:30:00', '06', '2005/03/12', 3],
#  ['Estacion3', '6:40:00', '06', '2005/03/12', 3],
#  ['Estacion3', '6:50:00', '06', '2005/03/12', 3],
#  ['Estacion3', '7:00:00', '07', '2005/03/12', 3],
#  ['Estacion3', '7:10:00', '07', '2005/03/12', 3],
#  ['Estacion3', '7:20:00', '07', '2005/03/12', 3],
#  ['Estacion3', '7:30:00', '07', '2005/03/12', 3],
#  ['Estacion3', '7:40:00', '07', '2005/03/12', 3],
#  ['Estacion3', '7:50:00', '07', '2005/03/12', 3],
#  ['Estacion3', '8:00:00', '08', '2005/03/12', 3],
#  ['Estacion3', '8:10:00', '08', '2005/03/12', 3],
#  ['Estacion3', '8:20:00', '08', '2005/03/12', 3],
#  ['Estacion3', '8:30:00', '08', '2005/03/12', 3],
#  ['Estacion3', '8:40:00', '08', '2005/03/12', 3],
#  ['Estacion3', '8:50:00', '08', '2005/03/12', 3],
#  ['Estacion3', '9:00:00', '09', '2005/03/12', 3],
#  ['Estacion3', '9:10:00', '09', '2005/03/12', 3],
#  ['Estacion3', '9:20:00', '09', '2005/03/12', 3],
#  ['Estacion3', '9:30:00', '09', '2005/03/12', 3],
#  ['Estacion3', '9:40:00', '09', '2005/03/12', 3],
#  ['Estacion3', '9:50:00', '09', '2005/03/12', 3],
#  ['Estacion3', '10:00:00', '10', '2005/03/12', 3],
#  ['Estacion3', '10:10:00', '10', '2005/03/12', 3],
#  ['Estacion3', '10:20:00', '10', '2005/03/12', 3],
#  ['Estacion3', '10:30:00', '10', '2005/03/12', 3],
#  ['Estacion3', '10:40:00', '10', '2005/03/12', 3],
#  ['Estacion3', '10:50:00', '10', '2005/03/12', 3],
#  ['Estacion3', '11:00:00', '11', '2005/03/12', 3],
#  ['Estacion3', '11:10:00', '11', '2005/03/12', 3],
#  ['Estacion3', '11:20:00', '11', '2005/03/12', 3],
#  ['Estacion3', '11:30:00', '11', '2005/03/12', 3],
#  ['Estacion3', '11:40:00', '11', '2005/03/12', 3],
#  ['Estacion3', '11:50:00', '11', '2005/03/12', 3],
#  ['Estacion3', '12:00:00', '12', '2005/03/12', 3],
#  ['Estacion3', '12:10:00', '12', '2005/03/12', 3],
#  ['Estacion3', '12:20:00', '12', '2005/03/12', 3],
#  ['Estacion3', '12:30:00', '12', '2005/03/12', 3],
#  ['Estacion3', '12:40:00', '12', '2005/03/12', 3],
#  ['Estacion3', '12:50:00', '12', '2005/03/12', 3],
#  ['Estacion3', '13:00:00', '13', '2005/03/12', 3],
#  ['Estacion3', '13:10:00', '13', '2005/03/12', 3],
#  ['Estacion3', '13:20:00', '13', '2005/03/12', 3],
#  ['Estacion3', '13:30:00', '13', '2005/03/12', 3],
#  ['Estacion3', '13:40:00', '13', '2005/03/12', 3],
#  ['Estacion3', '13:50:00', '13', '2005/03/12', 3],
#  ['Estacion3', '14:00:00', '14', '2005/03/12', 3],
#  ['Estacion3', '14:10:00', '14', '2005/03/12', 3],
#  ['Estacion3', '14:20:00', '14', '2005/03/12', 3],
#  ['Estacion3', '14:30:00', '14', '2005/03/12', 3],
#  ['Estacion3', '14:40:00', '14', '2005/03/12', 3],
#  ['Estacion3', '14:50:00', '14', '2005/03/12', 3],
#  ['Estacion3', '15:00:00', '15', '2005/03/12', 3],
#  ['Estacion3', '15:10:00', '15', '2005/03/12', 3],
#  ['Estacion3', '15:20:00', '15', '2005/03/12', 3],
#  ['Estacion3', '15:30:00', '15', '2005/03/12', 3],
#  ['Estacion3', '15:40:00', '15', '2005/03/12', 3],
#  ['Estacion3', '15:50:00', '15', '2005/03/12', 3],
#  ['Estacion3', '16:00:00', '16', '2005/03/12', 3],
#  ['Estacion3', '16:10:00', '16', '2005/03/12', 3],
#  ['Estacion3', '16:20:00', '16', '2005/03/12', 3],
#  ['Estacion3', '16:30:00', '16', '2005/03/12', 3],
#  ['Estacion3', '16:40:00', '16', '2005/03/12', 3],
#  ['Estacion3', '16:50:00', '16', '2005/03/12', 3],
#  ['Estacion3', '17:00:00', '17', '2005/03/12', 3],
#  ['Estacion3', '17:10:00', '17', '2005/03/12', 3],
#  ['Estacion3', '17:20:00', '17', '2005/03/12', 3],
#  ['Estacion3', '17:30:00', '17', '2005/03/12', 3],
#  ['Estacion3', '17:40:00', '17', '2005/03/12', 3],
#  ['Estacion3', '17:50:00', '17', '2005/03/12', 3],
#  ['Estacion3', '18:00:00', '18', '2005/03/12', 3],
#  ['Estacion3', '18:10:00', '18', '2005/03/12', 3],
#  ['Estacion3', '18:20:00', '18', '2005/03/12', 3],
#  ['Estacion3', '18:30:00', '18', '2005/03/12', 3],
#  ['Estacion3', '18:40:00', '18', '2005/03/12', 3],
#  ['Estacion3', '18:50:00', '18', '2005/03/12', 3],
#  ['Estacion3', '19:00:00', '19', '2005/03/12', 3],
#  ['Estacion3', '19:10:00', '19', '2005/03/12', 3],
#  ['Estacion3', '19:20:00', '19', '2005/03/12', 3],
#  ['Estacion3', '19:30:00', '19', '2005/03/12', 3],
#  ['Estacion3', '19:40:00', '19', '2005/03/12', 3],
#  ['Estacion3', '19:50:00', '19', '2005/03/12', 3],
#  ['Estacion3', '20:00:00', '20', '2005/03/12', 3],
#  ['Estacion3', '20:10:00', '20', '2005/03/12', 3],
#  ['Estacion3', '20:20:00', '20', '2005/03/12', 3],
#  ['Estacion3', '20:30:00', '20', '2005/03/12', 3],
#  ['Estacion3', '20:40:00', '20', '2005/03/12', 3],
#  ['Estacion3', '20:50:00', '20', '2005/03/12', 3],
#  ['Estacion3', '21:00:00', '21', '2005/03/12', 3],
#  ['Estacion3', '21:10:00', '21', '2005/03/12', 3],
#  ['Estacion3', '21:20:00', '21', '2005/03/12', 3],
#  ['Estacion3', '21:30:00', '21', '2005/03/12', 3],
#  ['Estacion3', '21:40:00', '21', '2005/03/12', 3],
#  ['Estacion3', '21:50:00', '21', '2005/03/12', 3],
#  ['Estacion3', '22:00:00', '22', '2005/03/12', 3],
#  ['Estacion3', '22:10:00', '22', '2005/03/12', 3],
#  ['Estacion3', '22:20:00', '22', '2005/03/12', 3],
#  ['Estacion3', '22:30:00', '22', '2005/03/12', 3],
#  ['Estacion3', '22:40:00', '22', '2005/03/12', 3],
#  ['Estacion3', '22:50:00', '22', '2005/03/12', 3],
#  ['Estacion3', '0:00:00', '00', '2005/03/13', 3],
#  ['Estacion3', '0:10:00', '00', '2005/03/13', 3],
#  ['Estacion3', '0:20:00', '00', '2005/03/13', 3],
#  ['Estacion3', '0:30:00', '00', '2005/03/13', 3],
#  ['Estacion3', '0:40:00', '00', '2005/03/13', 3],
#  ['Estacion3', '0:50:00', '00', '2005/03/13', 3],
#  ['Estacion3', '1:00:00', '01', '2005/03/13', 3],
#  ['Estacion3', '1:10:00', '01', '2005/03/13', 3],
#  ['Estacion3', '1:20:00', '01', '2005/03/13', 3],
#  ['Estacion3', '1:30:00', '01', '2005/03/13', 3],
#  ['Estacion3', '1:40:00', '01', '2005/03/13', 3],
#  ['Estacion3', '1:50:00', '01', '2005/03/13', 3],
#  ['Estacion3', '2:00:00', '02', '2005/03/13', 3],
#  ['Estacion3', '2:10:00', '02', '2005/03/13', 3],
#  ['Estacion3', '2:20:00', '02', '2005/03/13', 3],
#  ['Estacion3', '2:30:00', '02', '2005/03/13', 3],
#  ['Estacion3', '2:40:00', '02', '2005/03/13', 3],
#  ['Estacion3', '2:50:00', '02', '2005/03/13', 3],
#  ['Estacion3', '3:00:00', '03', '2005/03/13', 3],
#  ['Estacion3', '3:10:00', '03', '2005/03/13', 3],
#  ['Estacion3', '3:20:00', '03', '2005/03/13', 3],
#  ['Estacion3', '3:30:00', '03', '2005/03/13', 3],
#  ['Estacion3', '3:40:00', '03', '2005/03/13', 3],
#  ['Estacion3', '3:50:00', '03', '2005/03/13', 3],
#  ['Estacion3', '4:00:00', '04', '2005/03/13', 3],
#  ['Estacion3', '4:10:00', '04', '2005/03/13', 3],
#  ['Estacion3', '4:20:00', '04', '2005/03/13', 3],
#  ['Estacion3', '4:30:00', '04', '2005/03/13', 3],
#  ['Estacion3', '4:40:00', '04', '2005/03/13', 3],
#  ['Estacion3', '4:50:00', '04', '2005/03/13', 3],
#  ['Estacion3', '5:00:00', '05', '2005/03/13', 3],
#  ['Estacion3', '5:10:00', '05', '2005/03/13', 3],
#  ['Estacion3', '5:20:00', '05', '2005/03/13', 3],
#  ['Estacion3', '5:30:00', '05', '2005/03/13', 3],
#  ['Estacion3', '5:40:00', '05', '2005/03/13', 3],
#  ['Estacion3', '5:50:00', '05', '2005/03/13', 3],
#  ['Estacion3', '6:00:00', '06', '2005/03/13', 3],
#  ['Estacion3', '6:10:00', '06', '2005/03/13', 3],
#  ['Estacion3', '6:20:00', '06', '2005/03/13', 3],
#  ['Estacion3', '6:30:00', '06', '2005/03/13', 3],
#  ['Estacion3', '6:40:00', '06', '2005/03/13', 3],
#  ['Estacion3', '6:50:00', '06', '2005/03/13', 3],
#  ['Estacion3', '7:00:00', '07', '2005/03/13', 3],
#  ['Estacion3', '7:10:00', '07', '2005/03/13', 3],
#  ['Estacion3', '7:20:00', '07', '2005/03/13', 3],
#  ['Estacion3', '7:30:00', '07', '2005/03/13', 3],
#  ['Estacion3', '7:40:00', '07', '2005/03/13', 3],
#  ['Estacion3', '7:50:00', '07', '2005/03/13', 3],
#  ['Estacion3', '8:00:00', '08', '2005/03/13', 3],
#  ['Estacion3', '8:10:00', '08', '2005/03/13', 3],
#  ['Estacion3', '8:20:00', '08', '2005/03/13', 3],
#  ['Estacion3', '8:30:00', '08', '2005/03/13', 3],
#  ['Estacion3', '8:40:00', '08', '2005/03/13', 3],
#  ['Estacion3', '8:50:00', '08', '2005/03/13', 3],
#  ['Estacion3', '9:00:00', '09', '2005/03/13', 3],
#  ['Estacion3', '9:10:00', '09', '2005/03/13', 3],
#  ['Estacion3', '9:20:00', '09', '2005/03/13', 3],
#  ['Estacion3', '9:30:00', '09', '2005/03/13', 3],
#  ['Estacion3', '9:40:00', '09', '2005/03/13', 3],
#  ['Estacion3', '9:50:00', '09', '2005/03/13', 3],
#  ['Estacion3', '10:00:00', '10', '2005/03/13', 3],
#  ['Estacion3', '10:10:00', '10', '2005/03/13', 3],
#  ['Estacion3', '10:20:00', '10', '2005/03/13', 3],
#  ['Estacion3', '10:30:00', '10', '2005/03/13', 3],
#  ['Estacion3', '10:40:00', '10', '2005/03/13', 3],
#  ['Estacion3', '10:50:00', '10', '2005/03/13', 3],
#  ['Estacion3', '11:00:00', '11', '2005/03/13', 3],
#  ['Estacion3', '11:10:00', '11', '2005/03/13', 3],
#  ['Estacion3', '11:20:00', '11', '2005/03/13', 3],
#  ['Estacion3', '11:30:00', '11', '2005/03/13', 3],
#  ['Estacion3', '11:40:00', '11', '2005/03/13', 3],
#  ['Estacion3', '11:50:00', '11', '2005/03/13', 3],
#  ['Estacion3', '12:00:00', '12', '2005/03/13', 3],
#  ['Estacion3', '12:10:00', '12', '2005/03/13', 3],
#  ['Estacion3', '12:20:00', '12', '2005/03/13', 3],
#  ['Estacion3', '12:30:00', '12', '2005/03/13', 3],
#  ['Estacion3', '12:40:00', '12', '2005/03/13', 3],
#  ['Estacion3', '12:50:00', '12', '2005/03/13', 3],
#  ['Estacion3', '13:00:00', '13', '2005/03/13', 3],
#  ['Estacion3', '13:10:00', '13', '2005/03/13', 3],
#  ['Estacion3', '13:20:00', '13', '2005/03/13', 3],
#  ['Estacion3', '13:30:00', '13', '2005/03/13', 3],
#  ['Estacion3', '13:40:00', '13', '2005/03/13', 3],
#  ['Estacion3', '13:50:00', '13', '2005/03/13', 3],
#  ['Estacion3', '14:00:00', '14', '2005/03/13', 3],
#  ['Estacion3', '14:10:00', '14', '2005/03/13', 3],
#  ['Estacion3', '14:20:00', '14', '2005/03/13', 3],
#  ['Estacion3', '14:30:00', '14', '2005/03/13', 3],
#  ['Estacion3', '14:40:00', '14', '2005/03/13', 3],
#  ['Estacion3', '14:50:00', '14', '2005/03/13', 3],
#  ['Estacion3', '15:00:00', '15', '2005/03/13', 3],
#  ['Estacion3', '15:10:00', '15', '2005/03/13', 3],
#  ['Estacion3', '15:20:00', '15', '2005/03/13', 3],
#  ['Estacion3', '15:30:00', '15', '2005/03/13', 3],
#  ['Estacion3', '15:40:00', '15', '2005/03/13', 3],
#  ['Estacion3', '15:50:00', '15', '2005/03/13', 3],
#  ['Estacion3', '16:00:00', '16', '2005/03/13', 3],
#  ['Estacion3', '16:10:00', '16', '2005/03/13', 3],
#  ['Estacion3', '16:20:00', '16', '2005/03/13', 3],
#  ['Estacion3', '16:30:00', '16', '2005/03/13', 3],
#  ['Estacion3', '16:40:00', '16', '2005/03/13', 3],
#  ['Estacion3', '16:50:00', '16', '2005/03/13', 3],
#  ['Estacion3', '17:00:00', '17', '2005/03/13', 3],
#  ['Estacion3', '17:10:00', '17', '2005/03/13', 3],
#  ['Estacion3', '17:20:00', '17', '2005/03/13', 3],
#  ['Estacion3', '17:30:00', '17', '2005/03/13', 3],
#  ['Estacion3', '17:40:00', '17', '2005/03/13', 3],
#  ['Estacion3', '17:50:00', '17', '2005/03/13', 3],
#  ['Estacion3', '18:00:00', '18', '2005/03/13', 3],
#  ['Estacion3', '18:10:00', '18', '2005/03/13', 3],
#  ['Estacion3', '18:20:00', '18', '2005/03/13', 3],
#  ['Estacion3', '18:30:00', '18', '2005/03/13', 3],
#  ['Estacion3', '18:40:00', '18', '2005/03/13', 3],
#  ['Estacion3', '18:50:00', '18', '2005/03/13', 3],
#  ['Estacion3', '19:00:00', '19', '2005/03/13', 3],
#  ['Estacion3', '19:10:00', '19', '2005/03/13', 3],
#  ['Estacion3', '19:20:00', '19', '2005/03/13', 3],
#  ['Estacion3', '19:30:00', '19', '2005/03/13', 3],
#  ['Estacion3', '19:40:00', '19', '2005/03/13', 3],
#  ['Estacion3', '19:50:00', '19', '2005/03/13', 3],
#  ['Estacion3', '20:00:00', '20', '2005/03/13', 3],
#  ['Estacion3', '20:10:00', '20', '2005/03/13', 3],
#  ['Estacion3', '20:20:00', '20', '2005/03/13', 3],
#  ['Estacion3', '20:30:00', '20', '2005/03/13', 3],
#  ['Estacion3', '20:40:00', '20', '2005/03/13', 3],
#  ['Estacion3', '20:50:00', '20', '2005/03/13', 3],
#  ['Estacion3', '21:00:00', '21', '2005/03/13', 3],
#  ['Estacion3', '21:10:00', '21', '2005/03/13', 3],
#  ['Estacion3', '21:20:00', '21', '2005/03/13', 3],
#  ['Estacion3', '21:30:00', '21', '2005/03/13', 3],
#  ['Estacion3', '21:40:00', '21', '2005/03/13', 3],
#  ['Estacion3', '21:50:00', '21', '2005/03/13', 3],
#  ['Estacion3', '22:00:00', '22', '2005/03/13', 3],
#  ['Estacion3', '22:10:00', '22', '2005/03/13', 3],
#  ['Estacion3', '22:20:00', '22', '2005/03/13', 3],
#  ['Estacion3', '22:30:00', '22', '2005/03/13', 3],
#  ['Estacion3', '22:40:00', '22', '2005/03/13', 3],
#  ['Estacion3', '22:50:00', '22', '2005/03/13', 3],
#  ['Estacion3', '23:00:00', '23', '2005/03/13', 3],
#  ['Estacion3', '23:10:00', '23', '2005/03/13', 3],
#  ['Estacion3', '23:20:00', '23', '2005/03/13', 3],
#  ['Estacion3', '23:30:00', '23', '2005/03/13', 3],
#  ['Estacion3', '23:40:00', '23', '2005/03/13', 3],
#  ['Estacion3', '23:50:00', '23', '2005/03/13', 3],
#  ['Estacion3', '0:00:00', '00', '2005/03/14', 3],
#  ['Estacion3', '0:10:00', '00', '2005/03/14', 3],
#  ['Estacion3', '0:20:00', '00', '2005/03/14', 3],
#  ['Estacion3', '0:30:00', '00', '2005/03/14', 3],
#  ['Estacion3', '0:40:00', '00', '2005/03/14', 3],
#  ['Estacion3', '0:50:00', '00', '2005/03/14', 3],
#  ['Estacion3', '1:00:00', '01', '2005/03/14', 3],
#  ['Estacion3', '1:10:00', '01', '2005/03/14', 3],
#  ['Estacion3', '1:20:00', '01', '2005/03/14', 3],
#  ['Estacion3', '1:30:00', '01', '2005/03/14', 3],
#  ['Estacion3', '1:40:00', '01', '2005/03/14', 3],
#  ['Estacion3', '1:50:00', '01', '2005/03/14', 3],
#  ['Estacion3', '2:00:00', '02', '2005/03/14', 3],
#  ['Estacion3', '2:10:00', '02', '2005/03/14', 3],
#  ['Estacion3', '2:20:00', '02', '2005/03/14', 3],
#  ['Estacion3', '2:30:00', '02', '2005/03/14', 3],
#  ['Estacion3', '2:40:00', '02', '2005/03/14', 3],
#  ['Estacion3', '2:50:00', '02', '2005/03/14', 3],
#  ['Estacion3', '3:00:00', '03', '2005/03/14', 3],
#  ['Estacion3', '3:10:00', '03', '2005/03/14', 3],
#  ['Estacion3', '3:20:00', '03', '2005/03/14', 3],
#  ['Estacion3', '3:30:00', '03', '2005/03/14', 3],
#  ['Estacion3', '3:40:00', '03', '2005/03/14', 3],
#  ['Estacion3', '3:50:00', '03', '2005/03/14', 3],
#  ['Estacion3', '5:00:00', '05', '2005/03/14', 3],
#  ['Estacion3', '5:10:00', '05', '2005/03/14', 3],
#  ['Estacion3', '5:20:00', '05', '2005/03/14', 3],
#  ['Estacion3', '5:30:00', '05', '2005/03/14', 3],
#  ['Estacion3', '5:40:00', '05', '2005/03/14', 3],
#  ['Estacion3', '5:50:00', '05', '2005/03/14', 3],
#  ['Estacion3', '6:00:00', '06', '2005/03/14', 3],
#  ['Estacion3', '6:10:00', '06', '2005/03/14', 3],
#  ['Estacion3', '6:20:00', '06', '2005/03/14', 3],
#  ['Estacion3', '6:30:00', '06', '2005/03/14', 3],
#  ['Estacion3', '6:40:00', '06', '2005/03/14', 3],
#  ['Estacion3', '6:50:00', '06', '2005/03/14', 3],
#  ['Estacion3', '7:00:00', '07', '2005/03/14', 3],
#  ['Estacion3', '7:10:00', '07', '2005/03/14', 3],
#  ['Estacion3', '7:20:00', '07', '2005/03/14', 3],
#  ['Estacion3', '7:30:00', '07', '2005/03/14', 3],
#  ['Estacion3', '7:40:00', '07', '2005/03/14', 3],
#  ['Estacion3', '7:50:00', '07', '2005/03/14', 3],
#  ['Estacion3', '8:00:00', '08', '2005/03/14', 3],
#  ['Estacion3', '8:10:00', '08', '2005/03/14', 3],
#  ['Estacion3', '8:20:00', '08', '2005/03/14', 3],
#  ['Estacion3', '8:30:00', '08', '2005/03/14', 3],
#  ['Estacion3', '8:40:00', '08', '2005/03/14', 3],
#  ['Estacion3', '8:50:00', '08', '2005/03/14', 3],
#  ['Estacion3', '9:00:00', '09', '2005/03/14', 3],
#  ['Estacion3', '9:10:00', '09', '2005/03/14', 3],
#  ['Estacion3', '9:20:00', '09', '2005/03/14', 3],
#  ['Estacion3', '9:30:00', '09', '2005/03/14', 3],
#  ['Estacion3', '9:40:00', '09', '2005/03/14', 3],
#  ['Estacion3', '9:50:00', '09', '2005/03/14', 3],
#  ['Estacion3', '10:00:00', '10', '2005/03/14', 3],
#  ['Estacion3', '10:10:00', '10', '2005/03/14', 3],
#  ['Estacion3', '10:20:00', '10', '2005/03/14', 3],
#  ['Estacion3', '10:30:00', '10', '2005/03/14', 3],
#  ['Estacion3', '10:40:00', '10', '2005/03/14', 3],
#  ['Estacion3', '10:50:00', '10', '2005/03/14', 3],
#  ['Estacion3', '11:00:00', '11', '2005/03/14', 3],
#  ['Estacion3', '11:10:00', '11', '2005/03/14', 3],
#  ['Estacion3', '11:20:00', '11', '2005/03/14', 3],
#  ['Estacion3', '11:30:00', '11', '2005/03/14', 3],
#  ['Estacion3', '11:40:00', '11', '2005/03/14', 3],
#  ['Estacion3', '11:50:00', '11', '2005/03/14', 3],
#  ['Estacion3', '13:00:00', '13', '2005/03/14', 3],
#  ['Estacion3', '13:10:00', '13', '2005/03/14', 3],
#  ['Estacion3', '13:20:00', '13', '2005/03/14', 3],
#  ['Estacion3', '13:30:00', '13', '2005/03/14', 3],
#  ['Estacion3', '13:40:00', '13', '2005/03/14', 3],
#  ['Estacion3', '13:50:00', '13', '2005/03/14', 3],
#  ['Estacion3', '14:00:00', '14', '2005/03/14', 3],
#  ['Estacion3', '14:10:00', '14', '2005/03/14', 3],
#  ['Estacion3', '14:20:00', '14', '2005/03/14', 3],
#  ['Estacion3', '14:30:00', '14', '2005/03/14', 3],
#  ['Estacion3', '14:40:00', '14', '2005/03/14', 3],
#  ['Estacion3', '14:50:00', '14', '2005/03/14', 3],
#  ['Estacion3', '15:00:00', '15', '2005/03/14', 3],
#  ['Estacion3', '15:10:00', '15', '2005/03/14', 3],
#  ['Estacion3', '15:20:00', '15', '2005/03/14', 3],
#  ['Estacion3', '15:30:00', '15', '2005/03/14', 3],
#  ['Estacion3', '15:40:00', '15', '2005/03/14', 3],
#  ['Estacion3', '15:50:00', '15', '2005/03/14', 3],
#  ['Estacion3', '16:00:00', '16', '2005/03/14', 3],
#  ['Estacion3', '16:10:00', '16', '2005/03/14', 3],
#  ['Estacion3', '16:20:00', '16', '2005/03/14', 3],
#  ['Estacion3', '16:30:00', '16', '2005/03/14', 3],
#  ['Estacion3', '16:40:00', '16', '2005/03/14', 3],
#  ['Estacion3', '16:50:00', '16', '2005/03/14', 3],
#  ['Estacion3', '17:00:00', '17', '2005/03/14', 3],
#  ['Estacion3', '17:10:00', '17', '2005/03/14', 3],
#  ['Estacion3', '17:20:00', '17', '2005/03/14', 3],
#  ['Estacion3', '17:30:00', '17', '2005/03/14', 3],
#  ['Estacion3', '17:40:00', '17', '2005/03/14', 3],
#  ['Estacion3', '17:50:00', '17', '2005/03/14', 3],
#  ['Estacion3', '18:00:00', '18', '2005/03/14', 3],
#  ['Estacion3', '18:10:00', '18', '2005/03/14', 3],
#  ['Estacion3', '18:20:00', '18', '2005/03/14', 3],
#  ['Estacion3', '18:30:00', '18', '2005/03/14', 3],
#  ['Estacion3', '18:40:00', '18', '2005/03/14', 3],
#  ['Estacion3', '18:50:00', '18', '2005/03/14', 3],
#  ['Estacion3', '19:00:00', '19', '2005/03/14', 3],
#  ['Estacion3', '19:10:00', '19', '2005/03/14', 3],
#  ['Estacion3', '19:20:00', '19', '2005/03/14', 3],
#  ['Estacion3', '19:30:00', '19', '2005/03/14', 3],
#  ['Estacion3', '19:40:00', '19', '2005/03/14', 3],
#  ['Estacion3', '19:50:00', '19', '2005/03/14', 3],
#  ['Estacion3', '20:00:00', '20', '2005/03/14', 3],
#  ['Estacion3', '20:10:00', '20', '2005/03/14', 3],
#  ['Estacion3', '20:20:00', '20', '2005/03/14', 3],
#  ['Estacion3', '20:30:00', '20', '2005/03/14', 3],
#  ['Estacion3', '20:40:00', '20', '2005/03/14', 3],
#  ['Estacion3', '20:50:00', '20', '2005/03/14', 3],
#  ['Estacion3', '21:00:00', '21', '2005/03/14', 3],
#  ...]

# %%
import csv
Treque7=[['Nombre de la estacion','HHMMSS','Hora','Fecha','Mes']]
with open ('C:/Users/VERONICA/Desktop/SENA/5t/Final/Taller_estaciones_eolicas7.csv','w',newline='')as req7:
    writer=csv.writer(req7,delimiter=';')
    writer.writerows(Treque7)
    writer.writerows(tabla7)
    print('HECHO')
# Out:
# HECHO
