# %% [markdown]
# APRENDIZ: Veronica Perez Zea
#
# FICHA: 1751400
#
# FECHA DE INICIO: 2/12/2019
#
# TALLER ESTACIONES EOLICAS

# %% [markdown]
# REQUERIMIENTO Nº5
#
# Generar una tabla que contenga las siguientes columnas:
#
# -Estación.
#
# -Mes.
#
# -Velocidad media para ese mes calculada sobre todos los datos.

# %%
import time,datetime
import pandas
def archivo (file):
    estacion5 = open('C:/Users/VERONICA/Desktop/SENA/5t/PYTHON/files/06/Estacion1.csv', 'r').readlines()
    estacion5 = estacion5[1:]
    estacion5 = [row[0:-1] for row in estacion5]
    estacion5 = [row.split(';') for row in estacion5]
    return estacion5

# %%
tabla5= archivo('C:/Users/VERONICA/Desktop/SENA/5t/PYTHON/files/06/Estacion1.csv')

# %%
[[row[0].lower()]for row in tabla5]
tabla5=[[str('Estacion1')]+ row for row in tabla5]

# %%
def cambio(s):
    return datetime.datetime.strptime(s,'%d/%m/%y').strftime('%Y/%m/%d')

# %%
tabla5= [[row[0],cambio(row[1]),row[2],row[3],row[4]] for row in tabla5]

# %%
def MONTH(s):
    return datetime.datetime.strptime(s,'%Y/%m/%d').month

# %%
tabla5=[[MONTH(row[1])]+ row for row in tabla5]

# %%
tabla5=[[row[1],row[2],row[0]]for row in tabla5]

# %%
tabla5
# Out:
# [['Estacion1', '2005/04/16', 4],
#  ['Estacion1', '2005/04/16', 4],
#  ['Estacion1', '2005/04/16', 4],
#  ['Estacion1', '2005/04/16', 4],
#  ['Estacion1', '2005/04/16', 4],
#  ['Estacion1', '2005/04/16', 4],
#  ['Estacion1', '2005/04/16', 4],
#  ['Estacion1', '2005/04/16', 4],
#  ['Estacion1', '2005/04/16', 4],
#  ['Estacion1', '2005/04/16', 4],
#  ['Estacion1', '2005/04/16', 4],
#  ['Estacion1', '2005/04/16', 4],
#  ['Estacion1', '2005/04/16', 4],
#  ['Estacion1', '2005/04/16', 4],
#  ['Estacion1', '2005/04/16', 4],
#  ['Estacion1', '2005/04/16', 4],
#  ['Estacion1', '2005/04/16', 4],
#  ['Estacion1', '2005/04/16', 4],
#  ['Estacion1', '2005/04/16', 4],
#  ['Estacion1', '2005/04/16', 4],
#  ['Estacion1', '2005/04/16', 4],
#  ['Estacion1', '2005/04/16', 4],
#  ['Estacion1', '2005/04/16', 4],
#  ['Estacion1', '2005/04/16', 4],
#  ['Estacion1', '2005/04/16', 4],
#  ['Estacion1', '2005/04/16', 4],
#  ['Estacion1', '2005/04/16', 4],
#  ['Estacion1', '2005/04/16', 4],
# ...

# %%
import csv
Treque5=[['Nombre de la estacion','Fecha','Mes']]
with open ('C:/Users/VERONICA/Desktop/SENA/5t/Final/Taller_estaciones_eolicas5.csv','w',newline='')as req5:
    writer=csv.writer(req5,delimiter=';')
    writer.writerows(Treque5)
    writer.writerows(tabla5)
    print('HECHO')
# Out:
# HECHO
